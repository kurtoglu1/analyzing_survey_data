# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
survey_data_raw = np.genfromtxt('c:/users/admin/documents/code/pennylane/classification/umfrage_datensatz.csv', delimiter=';', names=True)

# %%
df = pd.DataFrame(data=survey_data_raw)

# %%
df.plot(x='Smartphone', y='Webrowser')
# Out:
# <AxesSubplot:xlabel='Smartphone'>

# %%
df.plot(x='Webrowser', y='Smartphone')
# Out:
# <AxesSubplot:xlabel='Webrowser'>

# %%
df.plot(x='Nutzungszeit', y='Mehrwert')
# Out:
# <AxesSubplot:xlabel='Nutzungszeit'>

# %%
df.plot(x='Mehrwert', y='Nutzungszeit')
# Out:
# <AxesSubplot:xlabel='Mehrwert'>

# %%
print(df)
# Out:
#     Smartphone  Webrowser  Screen  Andere  ...  Mehrwert  Alter  Geschlecht  Wohnort
# 0          1.0        2.0     2.0     2.0  ...       3.0    4.0         1.0      NaN
# 1          1.0        1.0     3.0     3.0  ...       2.0    3.0         1.0      NaN
# 2          2.0        2.0     2.0     2.0  ...       2.0    7.0         1.0      NaN
# 3          1.0        1.0     3.0     1.0  ...       4.0    7.0         1.0    -99.0
# 4          3.0        3.0     2.0     2.0  ...       3.0    4.0         1.0      NaN
# ..         ...        ...     ...     ...  ...       ...    ...         ...      ...
# 67         2.0        2.0     3.0     3.0  ...       3.0    5.0         2.0    -99.0
# 68         1.0        1.0     3.0     3.0  ...       3.0    3.0         2.0      NaN
# 69         1.0        1.0     2.0     1.0  ...       1.0    6.0         2.0      NaN
# 70         2.0        2.0     2.0     2.0  ...       2.0    5.0         2.0      NaN
# ...

# %%
print(survey_data_raw)
# Out:
# [(1., 2., 2., 2., 1., 0., 1., 0., 0., 1., 3., 2., 0., 1., 0., 2., 2., 3., 3., 4., 3., 4., 1.,  nan)
#  (1., 1., 3., 3., 1., 1., 1., 0., 1., 1., 2., 3., 0., 1., 1., 2., 2., 4., 2., 3., 2., 3., 1.,  nan)
#  (2., 2., 2., 2., 0., 1., 1., 0., 1., 0., 1., 4., 0., 0., 1., 2., 2., 4., 2., 3., 2., 7., 1.,  nan)
#  (1., 1., 3., 1., 0., 1., 1., 0., 1., 0., 3., 3., 0., 0., 0., 4., 4., 4., 4., 5., 4., 7., 1., -99.)
#  (3., 3., 2., 2., 1., 0., 1., 0., 0., 0., 3., 2., 1., 0., 0., 2., 3., 4., 4., 4., 3., 4., 1.,  nan)
#  (1., 1., 2., 2., 1., 0., 1., 0., 1., 0., 2., 1., 0., 0., 0., 2., 2., 4., 4., 4., 2., 3., 2.,  nan)
#  (1., 1., 3., 3., 0., 0., 0., 0., 1., 0., 3., 4., 1., 1., 0., 2., 3., 3., 4., 4., 3., 3., 2.,  nan)
#  (2., 2., 2., 1., 1., 0., 1., 0., 1., 0., 3., 3., 1., 0., 0., 3., 1., 3., 1., 5., 4., 4., 1.,  nan)
#  (1., 1., 2., 2., 1., 0., 1., 0., 1., 0., 3., 3., 0., 1., 0., 2., 3., 2., 4., 4., 3., 3., 2.,  nan)
# ...

# %%
df.plot(df[1], df[2])
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_5976/402503543.py", line 1, in <module>
#     df.plot(df[1], df[2])
#
#   File "C:\ProgramData\Miniconda3\envs\Quantum\lib\site-packages\pandas\plotting\_core.py", line 937, in __call__
#     elif not isinstance(data[x], ABCSeries):
#
#   File "C:\ProgramData\Miniconda3\envs\Quantum\lib\site-packages\pandas\core\frame.py", line 3464, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#
#   File "C:\ProgramData\Miniconda3\envs\Quantum\lib\site-packages\pandas\core\indexing.py", line 1314, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis)
#
#   File "C:\ProgramData\Miniconda3\envs\Quantum\lib\site-packages\pandas\core\indexing.py", line 1377, in _validate_read_indexer
#     raise KeyError(f"{not_found} not in index")
#
# KeyError: '[nan] not in index'

# %%
mehrwert = survey_data_raw[: , 20]

# %%
print(mehrwert)
# Out:
# [nan  3.  2.  2.  4.  3.  2.  3.  4.  3.  2.  4.  3.  1.  3.  2.  2.  2.
#   2.  2.  2.  2.  4.  2.  0.  3.  2.  2.  2.  1.  1.  2.  2.  3.  2.  2.
#   2.  2.  2.  2.  3.  0.  1.  3.  2.  2.  1.  2.  2.  4.  3.  2.  3.  4.
#   4.  0.  2.  2.  1.  0.  2.  2.  4.  1.  2.  3.  4.  2.  3.  3.  1.  2.
#   3.]

# %%
nutzung = survey_data_raw[: , 19]

# %%
print(nutzung)
# Out:
# [4. 3. 3. 5. 4. 4. 4. 5. 4. 2. 2. 4. 4. 3. 3. 3. 5. 2. 3. 2. 3. 5. 4. 0.
#  5. 2. 3. 3. 3. 3. 4. 3. 5. 3. 1. 3. 3. 3. 3. 3. 4. 3. 4. 2. 3. 2. 3. 2.
#  5. 4. 3. 5. 5. 5. 0. 2. 4. 2. 0. 5. 4. 5. 1. 4. 4. 3. 2. 4. 3. 3. 3. 4.]

# %%
sns.scatterplot(data=mehrwert)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=nutzung)
# Out:
# <AxesSubplot:>

# %%
nutzung_mehrwert_data = survey_data_raw[survey_data_raw[:, 19], survey_data_raw[:, 20]]
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_11496/2093104653.py", line 1, in <module>
#     nutzung_mehrwert_data = survey_data_raw[survey_data_raw[:, 19], survey_data_raw[:, 20]]
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
sns.scatterplot(data=survey_data_raw)
# Out:
# <AxesSubplot:>
