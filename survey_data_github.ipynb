# %%
#### Author: Daniel Kurtoglu
#### Module: MarktKomm
#### Date: 25.11.21

#### Analyzing if there are any correlations between different features of the survey we did

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
# %matplotlib inline

# %%
survey_data_raw = np.genfromtxt('c:/users/admin/documents/code/pennylane/classification/umfrage_datensatz.csv', delimiter=';', names=True)

# %%
survey_data = pd.DataFrame(data=survey_data_raw)

# %%
survey_data
# Out:
#     Smartphone  Webrowser  Screen  Andere  ...  Mehrwert  Alter  Geschlecht  Wohnort
# 0          1.0        2.0     2.0     2.0  ...       3.0    4.0         1.0      NaN
# 1          1.0        1.0     3.0     3.0  ...       2.0    3.0         1.0      NaN
# 2          2.0        2.0     2.0     2.0  ...       2.0    7.0         1.0      NaN
# 3          1.0        1.0     3.0     1.0  ...       4.0    7.0         1.0    -99.0
# 4          3.0        3.0     2.0     2.0  ...       3.0    4.0         1.0      NaN
# ..         ...        ...     ...     ...  ...       ...    ...         ...      ...
# 67         2.0        2.0     3.0     3.0  ...       3.0    5.0         2.0    -99.0
# 68         1.0        1.0     3.0     3.0  ...       3.0    3.0         2.0      NaN
# 69         1.0        1.0     2.0     1.0  ...       1.0    6.0         2.0      NaN
# 70         2.0        2.0     2.0     2.0  ...       2.0    5.0         2.0      NaN
# ...

# %%
sns.heatmap(survey_data.corr(), cbar=True, linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
####--- Mehrtwert ---####

# %%
np.corrcoef(survey_data['Mehrwert'], survey_data['Spielvergnügen'])
# Out:
# array([[1.        , 0.59672642],
#        [0.59672642, 1.        ]])

# %%
np.corrcoef(survey_data['Mehrwert'], survey_data['Gutscheine'])
# Out:
# array([[1.        , 0.45454545],
#        [0.45454545, 1.        ]])

# %%
np.corrcoef(survey_data['Mehrwert'], survey_data['Gewinnspiele'])
# Out:
# array([[1.        , 0.33460682],
#        [0.33460682, 1.        ]])

# %%
####--- Nutzungszeit ---####

# %%
np.corrcoef(survey_data['Nutzungszeit'], survey_data['Spielvergnügen'])
# Out:
# array([[1.        , 0.59245347],
#        [0.59245347, 1.        ]])

# %%
np.corrcoef(survey_data['Nutzungszeit'], survey_data['Gutscheine'])
# Out:
# array([[1.        , 0.61023418],
#        [0.61023418, 1.        ]])

# %%
np.corrcoef(survey_data['Nutzungszeit'], survey_data['Gewinnspiele'])
# Out:
# array([[1.        , 0.56676626],
#        [0.56676626, 1.        ]])

# %%
####--- Mix ---####

# %%
np.corrcoef(survey_data['Mehrwert'], survey_data['Nutzungszeit'])
# Out:
# array([[1.        , 0.64445292],
#        [0.64445292, 1.        ]])

# %%
############################--- höchste Korrelation ---###########################

# %%
np.corrcoef(survey_data['Gewinnspiele'], survey_data['Gutscheine'])
# Out:
# array([[1.        , 0.67350347],
#        [0.67350347, 1.        ]])

# %%
############################--- höchste Korrelation ---###########################

# %%
np.corrcoef(survey_data['Spielvergnügen'], survey_data['Gutscheine'])
# Out:
# array([[1.        , 0.44970687],
#        [0.44970687, 1.        ]])

# %%
np.corrcoef(survey_data['Gewinnspiele'], survey_data['Spielvergnügen'])
# Out:
# array([[1.        , 0.34881741],
#        [0.34881741, 1.        ]])

# %%
sns.scatterplot(y=survey_data['Mehrwert'], x=survey_data['Nutzungszeit'], hue=survey_data['Geschlecht'])
# Out:
# <AxesSubplot:xlabel='Nutzungszeit', ylabel='Mehrwert'>

# %%
sns.scatterplot(y=survey_data['Mehrwert'], x=survey_data['Nutzungszeit'], hue=survey_data['Alter'])
# Out:
# <AxesSubplot:xlabel='Nutzungszeit', ylabel='Mehrwert'>

# %%
sns.scatterplot(y=survey_data['Mehrwert'], x=survey_data['Nutzungszeit'], hue=survey_data['Spielvergnügen'])
# Out:
# <AxesSubplot:xlabel='Nutzungszeit', ylabel='Mehrwert'>

# %%
sns.scatterplot(y=survey_data['Mehrwert'], x=survey_data['Nutzungszeit'], hue=survey_data['Gutscheine'])
# Out:
# <AxesSubplot:xlabel='Nutzungszeit', ylabel='Mehrwert'>

# %%
sns.scatterplot(y=survey_data['Mehrwert'], x=survey_data['Nutzungszeit'], hue=survey_data['Gewinnspiele'])
# Out:
# <AxesSubplot:xlabel='Nutzungszeit', ylabel='Mehrwert'>
